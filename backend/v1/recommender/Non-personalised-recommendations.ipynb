# %%
import pandas as pd
import numpy as np
import scipy as sc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# ## Data Preparations

# %%
#read csv(s)
movies_df = pd.read_csv("dataset/movies_full.csv")
ratings_df = pd.read_csv("dataset/ratings.csv")
tags_df = pd.read_csv("dataset/tags.csv")
gscores_df = pd.read_csv("dataset/genome-scores.csv")
gtags_df = pd.read_csv("dataset/genome-tags.csv")
links_df = pd.read_csv("dataset/links.csv")

# %%
# print(ratings_df.duplicated)
# print(ratings_df.shape)
# print(ratings_df['userId'].nunique())

# %%
#drop timestamp as it is only consuming memory
ratings_df.drop('timestamp', axis=1, inplace=True)
tags_df.drop('timestamp', axis=1, inplace=True)
movies_df.drop(columns=(['imdbId', 'url', 'titleLower']), inplace=True)

# %%
movies_df.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres    year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 1                   Adventure|Children|Fantasy  1995.0
# 2                               Comedy|Romance  1995.0
# 3                         Comedy|Drama|Romance  1995.0
# 4                                       Comedy  1995.0

# %%
movies_2 = movies_df.copy()




movies_df['genres'] = movies_df['genres'].str.split('|')
movies_df['genres'] = movies_df['genres'].apply(lambda x: ', '.join(x)) 
# genres_encoded = movies_df['genres'].str.get_dummies(sep='|')
# movies_df['year'] = movies_df['title'].str.extract('\((\d{4})\)')


# movies_df['year'] = movies_df['year'].astype(int)
movies_df['decade'] = (movies_df['year'] // 10) * 10

movies_df['title'].replace('\((\d{4})\)', '', regex=True, inplace=True)
movies_df.head()


# Flatten the list of genres
movies_2['genres'] = movies_2['genres'].str.split('|')
all_genres = [genre for sublist in movies_2['genres'] for genre in sublist]

# Extract unique genres
unique_genres = list(set(all_genres))

# Sort the unique genres for better readability (optional)
unique_genres.sort()

# Display the unique genres
# print(unique_genres)

del all_genres
del movies_2



# print(len(unique_genres))

# %%
print(ratings_df.isnull().sum())
ratings_df.head()
# Out:
# userId     0
# movieId    0
# rating     0
# dtype: int64
#    userId  movieId  rating
# 0       1      296     5.0
# 1       1      306     3.5
# 2       1      307     5.0
# 3       1      665     5.0
# 4       1      899     3.5

# %%
#print(tags_df.isnull().sum()) #It has 16 null tags
#print(tags_df[tags_df['tag'].isnull()].iloc[0])
tags_df.dropna(inplace=True)
print(tags_df.isnull().sum())
tags_df.head()
# Out:
# userId     0
# movieId    0
# tag        0
# dtype: int64
#    userId  movieId               tag
# 0       3      260           classic
# 1       3      260            sci-fi
# 2       4     1732       dark comedy
# 3       4     1732    great dialogue
# 4       4     7569  so bad it's good

# %%
print(gscores_df.isnull().sum())
gscores_df.head()
# Out:
# movieId      0
# tagId        0
# relevance    0
# dtype: int64
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
print(gtags_df.isnull().sum())
gtags_df.head()
# Out:
# tagId    0
# tag      0
# dtype: int64
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
print(links_df.isnull().sum())
links_df.head()
# Out:
# movieId      0
# imdbId       0
# tmdbId     107
# dtype: int64
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies_rating_user_df = pd.merge(movies_df, ratings_df, on="movieId", how="inner")
movies_rating_user_df.head()
# Out:
#    movieId      title                                           genres  \
# 0        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 1        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 2        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 3        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 4        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
#
#      year  decade  userId  rating
# 0  1995.0  1990.0       2     3.5
# 1  1995.0  1990.0       3     4.0
# 2  1995.0  1990.0       4     3.0
# 3  1995.0  1990.0       5     4.0
# 4  1995.0  1990.0       8     4.0

# %%
movies_rating_df = movies_rating_user_df[['movieId', 'title', 'rating', 'genres', 'year', 'decade']].groupby(['movieId', 'title', 'genres', 'year', 'decade'])['rating'].agg(['count', 'mean']).round(1)
movies_rating_df.head()
# Out:
#                                                                                                    count  \
# movieId title                       genres                                          year   decade
# 1       Toy Story                   Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0  57309
# 2       Jumanji                     Adventure, Children, Fantasy                    1995.0 1990.0  24228
# 3       Grumpier Old Men            Comedy, Romance                                 1995.0 1990.0  11804
# 4       Waiting to Exhale           Comedy, Drama, Romance                          1995.0 1990.0   2523
# 5       Father of the Bride Part II Comedy                                          1995.0 1990.0  11714
#
#                                                                                                    mean
# movieId title                       genres                                          year   decade
# 1       Toy Story                   Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0   3.9
# 2       Jumanji                     Adventure, Children, Fantasy                    1995.0 1990.0   3.3
# 3       Grumpier Old Men            Comedy, Romance                                 1995.0 1990.0   3.1
# 4       Waiting to Exhale           Comedy, Drama, Romance                          1995.0 1990.0   2.9
# 5       Father of the Bride Part II Comedy                                          1995.0 1990.0   3.1

# %%
movies_rating_df.sort_values('count', ascending=False, inplace=True)
movies_rating_df.rename(columns={'count' : 'Num_ratings', 'mean': 'Average_rating'}, inplace=True)
movies_rating_df.head(15)
# Out:
#                                                                                                                           Num_ratings  \
# movieId title                                              genres                                          year   decade
# 356     Forrest Gump                                       Comedy, Drama, Romance, War                     1994.0 1990.0        81491
# 318     Shawshank Redemption, The                          Crime, Drama                                    1994.0 1990.0        81482
# 296     Pulp Fiction                                       Comedy, Crime, Drama, Thriller                  1994.0 1990.0        79672
# 593     Silence of the Lambs, The                          Crime, Horror, Thriller                         1991.0 1990.0        74127
# 2571    Matrix, The                                        Action, Sci-Fi, Thriller                        1999.0 1990.0        72674
# 260     Star Wars: Episode IV - A New Hope                 Action, Adventure, Sci-Fi                       1977.0 1970.0        68717
# 480     Jurassic Park                                      Action, Adventure, Sci-Fi, Thriller             1993.0 1990.0        64144
# 527     Schindler's List                                   Drama, War                                      1993.0 1990.0        60411
# 110     Braveheart                                         Action, Drama, War                              1995.0 1990.0        59184
# 2959    Fight Club                                         Action, Crime, Drama, Thriller                  1999.0 1990.0        58773
# 589     Terminator 2: Judgment Day                         Action, Sci-Fi                                  1991.0 1990.0        57379
# 1196    Star Wars: Episode V - The Empire Strikes Back     Action, Adventure, Sci-Fi                       1980.0 1980.0        57361
# 1       Toy Story                                          Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0        57309
# 4993    Lord of the Rings: The Fellowship of the Ring, The Adventure, Fantasy                              2001.0 2000.0        55736
# 50      Usual Suspects, The                                Crime, Mystery, Thriller                        1995.0 1990.0        55366
#
#                                                                                                                           Average_rating
# movieId title                                              genres                                          year   decade
# 356     Forrest Gump                                       Comedy, Drama, Romance, War                     1994.0 1990.0             4.0
# 318     Shawshank Redemption, The                          Crime, Drama                                    1994.0 1990.0             4.4
# 296     Pulp Fiction                                       Comedy, Crime, Drama, Thriller                  1994.0 1990.0             4.2
# 593     Silence of the Lambs, The                          Crime, Horror, Thriller                         1991.0 1990.0             4.2
# 2571    Matrix, The                                        Action, Sci-Fi, Thriller                        1999.0 1990.0             4.2
# 260     Star Wars: Episode IV - A New Hope                 Action, Adventure, Sci-Fi                       1977.0 1970.0             4.1
# 480     Jurassic Park                                      Action, Adventure, Sci-Fi, Thriller             1993.0 1990.0             3.7
# 527     Schindler's List                                   Drama, War                                      1993.0 1990.0             4.2
# 110     Braveheart                                         Action, Drama, War                              1995.0 1990.0             4.0
# 2959    Fight Club                                         Action, Crime, Drama, Thriller                  1999.0 1990.0             4.2
# 589     Terminator 2: Judgment Day                         Action, Sci-Fi                                  1991.0 1990.0             3.9
# 1196    Star Wars: Episode V - The Empire Strikes Back     Action, Adventure, Sci-Fi                       1980.0 1980.0             4.1
# 1       Toy Story                                          Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0             3.9
# 4993    Lord of the Rings: The Fellowship of the Ring, The Adventure, Fantasy                              2001.0 2000.0             4.1
# 50      Usual Suspects, The                                Crime, Mystery, Thriller                        1995.0 1990.0             4.3

# %% [markdown]
# # Data Preprocessing

# %%
#let's use the beysian average to calculate a more accurate rating
#this is because a review of 5 with only 1 review is worthless, while a 4.2 with multiple reviews is more reliable

def calculate_weighted_rating(df, C, m):
    """
    Calculate Bayesian weighted rating for each movie in the DataFrame.

    Parameters:
    df (DataFrame): DataFrame containing movie ratings.
    C (float): Average rating across all movies (prior assumption).
    m (int): Minimum number of ratings required to be considered.

    Returns:
    DataFrame: DataFrame with Bayesian weighted rating column added.
    """
    
    # Add the Bayesian weighted rating as a new column in the DataFrame
    df['Bayesian_rating'] = (df['Num_ratings'] / (df['Num_ratings'] + m)) * df['Average_rating'] + (m / (df['Num_ratings'] + m)) * C

    return df

C = round(ratings_df['rating'].mean(), 2)
movies_rating_df = calculate_weighted_rating(movies_rating_df, C, 500)
movies_rating_df.drop(columns='Average_rating', inplace=True)
movies_rating_df.sort_values(by='Bayesian_rating', ascending=False, inplace=True)
movies_rating_df.head()
# Out:
#                                                                           Num_ratings  \
# movieId title                     genres                   year   decade
# 318     Shawshank Redemption, The Crime, Drama             1994.0 1990.0        81482
# 50      Usual Suspects, The       Crime, Mystery, Thriller 1995.0 1990.0        55366
# 858     Godfather, The            Crime, Drama             1972.0 1970.0        52498
# 1221    Godfather: Part II, The   Crime, Drama             1974.0 1970.0        34188
# 159817  Planet Earth              Documentary              2006.0 2000.0         1747
#
#                                                                           Bayesian_rating
# movieId title                     genres                   year   decade
# 318     Shawshank Redemption, The Crime, Drama             1994.0 1990.0         4.394694
# 50      Usual Suspects, The       Crime, Mystery, Thriller 1995.0 1990.0         4.293109
# 858     Godfather, The            Crime, Drama             1972.0 1970.0         4.292736
# 1221    Godfather: Part II, The   Crime, Drama             1974.0 1970.0         4.288901
# 159817  Planet Earth              Documentary              2006.0 2000.0         4.284157

# %% [markdown]
# # Non-personalized Recommendation System

# %% [markdown]
# ### This will be applied to the website if there isn't any user information, aka, one is not logged in.
#
# Despite not being logged in, recommendations will be provided such as:
# - Best movies overall
# - Best movies for each genre
# - Spoting trends
# - etc

# %%
# let's recommend the best movies of all time (doesn't matter the genre, only it's popularity)
def non_personalized_recommendations_overall_rating(num_movies, df):
    movies_best = df.copy()
    movies_best = movies_best.iloc[:num_movies]
    movies_best.reset_index(inplace=True)
    
    return movies_best[['movieId', 'title']]

print(non_personalized_recommendations_overall_rating(10, movies_rating_df))

# %%
#unique_genres is a list with all available genres

# Function to find the best movie for each genre
def find_best_movies_for_genres(df, possible_genres, num_of_movies):
    df_copy = df.copy()
    df_copy.reset_index(inplace=True)
    df_copy['genres'] = df_copy['genres'].str.split(', ')
    best_movies_for_genres = {}
    for genre in possible_genres:
        # Filter DataFrame by genre

        genre_df = df_copy[df_copy['genres'].apply(lambda x: genre in x)]
        if not genre_df.empty:
           
            # Select the top movie for the genre
            best_movie = genre_df[['movieId', 'title']].iloc[:num_of_movies]
            best_movies_for_genres[genre] = best_movie
    del df_copy
    del genre_df
    return best_movies_for_genres

# Find the best movie for each genre
best_movies_for_genres = find_best_movies_for_genres(movies_rating_df, unique_genres, 10)

# Display the best movies for each genre
for genre, movie in best_movies_for_genres.items():
    print(f"Best movie for genre '{genre}':")
    print(movie[['movieId', 'title']])
    print()

# %%
#best movies of a given year

def recommend_movies_best_year(df, year, num_movies):
    movies_year = df.copy()
    movies_year.reset_index(inplace=True)
    movies_year = movies_year[movies_year['year'] == year]
    movies_year_best = movies_year.iloc[:num_movies]
    del movies_year 
    
    
    return movies_year_best[['movieId', 'title', 'year']]

    
best_year_movies = recommend_movies_best_year(movies_rating_df, 2010, 10)
print(best_year_movies)
# Out:
#       movieId                                              title    year
# 13      79132                                          Inception  2010.0
# 174     74458                                     Shutter Island  2010.0
# 317     80906                                         Inside Job  2010.0
# 345     86345                              Louis C.K.: Hilarious  2010.0
# 376     85774                                              Senna  2010.0
# 390     81845                                 King's Speech, The  2010.0
# 391     78499                                        Toy Story 3  2010.0
# 394     81834       Harry Potter and the Deathly Hallows: Part 1  2010.0
# 396     76093                           How to Train Your Dragon  2010.0
# 402     85342  Elite Squad: The Enemy Within (Tropa de Elite ...  2010.0
# 474     86781                                          Incendies  2010.0
# 538     77455                         Exit Through the Gift Shop  2010.0
# 733     80463                                Social Network, The  2010.0
# 738     81591                                         Black Swan  2010.0
# 774     79702                        Scott Pilgrim vs. the World  2010.0
# 797     82459                                          True Grit  2010.0
# 866     81932                                       Fighter, The  2010.0
# 869    126430                                        The Pacific  2010.0
# 931     83134                              Tucker & Dale vs Evil  2010.0
# 1066    83132  Secret World of Arrietty, The (Kari-gurashi no...  2010.0
# 1148    79553                                           Ip Man 2  2010.0
# 1198    82667                  I Saw the Devil (Akmareul boatda)  2010.0
# 1365    79091                                      Despicable Me  2010.0
# 1401    81847                                            Tangled  2010.0
# 1452    86892                               The Man from Nowhere  2010.0
# 1481    80489                                          Town, The  2010.0
# 1540    84952                             Confessions (Kokuhaku)  2010.0
# 1563    83803                                        Day & Night  2010.0
# 1588    80586                                            Flipped  2010.0
# 1650    78574                                      Winter's Bone  2010.0
# 1687    78039                                     Blue Valentine  2010.0
# 1746    81788                               Next Three Days, The  2010.0
# 1750    80969                                    Never Let Me Go  2010.0
# 1801    87234                                          Submarine  2010.0
# 1836    77800                                         Four Lions  2010.0
# 1925    87304                                          Beginners  2010.0
# 1971    86142                13 Assassins (Jûsan-nin no shikaku)  2010.0
# 1980    84156                  Happy People: A Year in the Taiga  2010.0
# 1989    81257                         In a Better World (Hævnen)  2010.0
# 2029    79720                                     Animal Kingdom  2010.0
# 2088    86000                                                Boy  2010.0
# 2101    81018                 Illusionist, The (L'illusionniste)  2010.0
# 2121   121372                               Bill Burr: Let It Go  2010.0
# 2138    81158                                           Restrepo  2010.0
# 2140    80839                                        Secretariat  2010.0
# 2157    81817                                             Carlos  2010.0
# 2293    85394                           Cave of Forgotten Dreams  2010.0
# 2345    82463                                       Another Year  2010.0
# 2394    81191                             Waiting for 'Superman'  2010.0
# 2398    80185                                            GasLand  2010.0

# %%
#recommend the bets movies of a given decade

def recommend_movies_best_decade(df, decade, num_movies):
    movies_decade = df.copy()
    movies_decade.reset_index(inplace=True)
    movies_decade = movies_decade[movies_decade['decade'] == decade]
    movies_decade_best = movies_decade.iloc[:num_movies]
    del movies_decade 
    
    
    return movies_decade_best[['movieId', 'title']]#'decade','year',  'Bayesian_rating']]

    
best_year_movies = recommend_movies_best_decade(movies_rating_df, 2010, 10)
print(best_year_movies)
# Out:
#      movieId                              title
# 6     171011                    Planet Earth II
# 13     79132                          Inception
# 65    109487                       Interstellar
# 77     92259                       Intouchables
# 84    112552                           Whiplash
# 102   142488                          Spotlight
# 123   195159  Spider-Man: Into the Spider-Verse
# 124    96829                 Hunt, The (Jagten)
# 131    98491                           Paperman
# 167    99114                   Django Unchained
